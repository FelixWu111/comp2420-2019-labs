# %% [markdown]
# <h1 align='center'> COMP2420/COMP6420 - Introduction to Data Management, Analysis and Security</h1>
#
# <h2 align='center'> Homework Assessment 04</h2>
#
# *****
#
# Last **notebook** assessment ! We are close !
# The following 4 questions should test your understanding of the lecture and lab material taught during the lectures and the lab exercises in **Weeks 7 & 8**. In the **next lab (Lab 08)**, you'll be asked to complete any one of these exercises by your tutor in Exam Mode. Upon completion, you'll be marked by your tutor, based on the correctness and completeness of your solution.

# %%
# RUN THIS CELL TO IMPORT THE REQUIRED MODULES
# ALL MODULES REQUIRED IN THIS LAB TEST SHOULD ALREADY BE IMPORTED
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans, MeanShift
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from itertools import cycle
import matplotlib.pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
import warnings
warnings.filterwarnings("ignore")

# %%
# Dataset 1
sales_data = pd.read_csv('data/Sales.csv', index_col=0)
sales_data.head()
# Out:
#   Transaction_date   Product  Price Payment_Type               Name  \
# 0      1/2/09 6:17  Product1   1200   Mastercard           carolina
# 1      1/2/09 4:53  Product1   1200         Visa             Betina
# 2     1/2/09 13:08  Product1   1200   Mastercard  Federica e Andrea
# 3     1/3/09 14:44  Product1   1200         Visa              Gouya
# 4     1/4/09 12:56  Product2   3600         Visa            Gerd W
#
#                            City     State         Country Account_Created  \
# 0                      Basildon   England  United Kingdom     1/2/09 6:00
# 1  Parkville                           MO   United States     1/2/09 4:42
# 2  Astoria                             OR   United States    1/1/09 16:21
# 3                        Echuca  Victoria       Australia   9/25/05 21:13
# 4  Cahaba Heights                      AL   United States  11/15/08 15:47
#
#      Last_Login   Latitude   Longitude
# 0   1/2/09 6:08  51.500000   -1.116667
# 1   1/2/09 7:49  39.195000  -94.681940
# 2  1/3/09 12:32  46.188060 -123.830000
# 3  1/3/09 14:22 -36.133333  144.750000
# 4  1/4/09 12:45  33.520560  -86.802500

# %%
# Dataset 2
pokemon = pd.read_csv('data/pokemon.csv', index_col=0)
pokemon.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Dataset 1: Online Sales
#
# Talk about a lack of privacy. You have been supplied a dataset that has transaction data for online purchases. The dataset `Sales` has the following features:
#
# | **Feature**             | **Description**                     |
# | ----------------------- | ----------------------------------- |
# | Transaction_date        | Date of Transaction (DD/MM/YY H:Mi) |
# | Product                 | Name of Product Purchased           |
# | Price                   | Cost of the product purchased       |
# | Payment_Type            | Card Type used in the Transaction   |
# | Name                    | Entered Name of the User Account    |
# | City                    | City of User's residence            |
# | State                   | State of User's residence           |
# | Country                 | Country of User's residence         |
# | Account_Created         | Date of Acc. Creation (DD/MM/YY H:Mi)  |
# | Last_Login              | Date of Last Login (DD/MM/YY H:Mi)  |
# | Lattitude               | Lattitude of User's residence       |
# | Longitude               | Longitude of User's residence       |

# %% [markdown]
# ### Dataset 2: Priceless Pokemon
#
# Pokemon makes a return! As seen before, the pokemon dataset has the following features:
#
# | **Feature**             | **Description**                     |
# | ----------------------- | ----------------------------------- |
# | Name                    | Pokemon Name |
# | Type 1                  | Primary Type of Pokemon |
# | Type 2                   | Secondary Type of Pokemon       |
# | Total            | Numerical Value for Total of Pokemon stats   |
# | HP                    | Hit Points of the Pokemon                            |
# | Attack                    | Attack Points (Strength) of the Pokemon            |
# | Defense                   | Defense Points of the Pokemon          |
# | Sp. Atk                 | Special Attack of the Pokemon         |
# | Sp. Defense         | Special Defense of the Pokemon  |
# | Speed              | Speed of the Pokemon  |
# | Generation               | Generation the Pokemon was released in       |
# | Legendary               | Whether the Pokemon is a Legendary or not       |

# %% [markdown]
# ### Exercise 1: Lost Legendaries (Using Dataset #2)
#
# Its a tough decision to decide which pokemon are legendaries or not, we don't envy the creators. Perform the following tasks:
# - Split the data into _training_ and _testing_ sets, using **Generation 1,2 & 3** as the training data, and **Generation 4 & 5** as the testing data.
# - Implement a decision tree classifier (using sklearn or an equivalent packages) to predict whether a pokemon is a Legendary or not. Train the model on the 1-3 Generation Data and test the model's accuracy using the Generation 4-5 data. Use the 'entropy' criterion (see [doco](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html#sklearn.tree.DecisionTreeClassifier))
# - Provide the `Accuracy Score` as an accuracy metric.

# %%
# Part 1: Dataset Splitting
train_data = pokemon[(pokemon['Generation']==1)|(pokemon['Generation']==2)|(pokemon['Generation']==3)]
test_data = pokemon[(pokemon['Generation']==4)|(pokemon['Generation']==5)]
X_train = np.array(train_data[['Total','HP','Attack','Defense','Speed','Sp. Atk','Sp. Def']])
y_train = train_data.Legendary
X_test = np.array(test_data[['Total','HP','Attack','Defense','Speed','Sp. Atk','Sp. Def']])
y_test = test_data.Legendary
# Part 2: Decision Tree
clf_entropy = DecisionTreeClassifier(criterion = "entropy", random_state = 100,
 max_depth=3, min_samples_leaf=5)
clf_entropy.fit(X_train, y_train)
y_pred = clf_entropy.predict(X_test)
# Part 3: Metric
print("Accuracy Score is ", accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy Score is  94.75524475524476

# %% [markdown]
# ***

# %% [markdown]
# ### Exercise 2: My Neighbour's Purchases (Using Dataset #1)
#
# Jane knows those around her are making purchases online and assumes based on other transaction data, it is possible to predict the Transaction_Type. Based on this, perform the following tasks:
# - Convert the *Payment_Type* & *Product* columns from textual data to numerical such that each *Payment_Type / Product* is represented by a numerical value (ie: "Mastercard":0, "Visa":1 etc)
# - Implement a KNN classification model to predict the **Payment_Type** of a transaction based on other features within the dataset with k=12. Provide the accuracy score of the model.
# - Is using 12 Neighbours ideal? How can we determine if it is ideal? Answer the question in the box provided.

# %%
# Part 1: Convert the Payment_Type column to numerical representation
sales_data['Payment_Type'] = sales_data['Payment_Type'].map({"Mastercard":0,"Visa":1,"Diners":2,"Amex":3})
sales_data['Product'] = sales_data['Product'].map({"Product1":1,"Product2":2,"Product3":3})
sales_data1 = sales_data[['Product','Price','Latitude','Longitude','Payment_Type']]
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)
clean_dataset(sales_data1)
X = sales_data1[['Product','Price','Latitude','Longitude']]
y = sales_data1['Payment_Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)  
# Part 2: Implement a KNN classification model & provide an accuracy score
classifier = KNeighborsClassifier(n_neighbors=12)
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)
print("Accuracy Score is ", accuracy_score(y_test,y_pred)*100)
# Out:
# Accuracy Score is  51.5

# %% [raw]
# Part 3: How can we determine the ideal number of neighbours to use?
#
# #### Your answer here #####
# You need to investigate performance of KNN near rule-of-thumb-value and make a decision about the optimal one using any algorithm of performance testing (such as KFCV).

# %% [markdown]
# ***

# %% [markdown]
# ### Exercise 3: A MeanShift away from the norm (Using Dataset #2)
#
# No more supervision! The adults have gone back to their table and its time to start working unsupervised, or at least your model will be. If you haven't noticed already, the `sklearn` module uses almost the same functionality for all their models, and this next exercise is a good example of that. Your tasks are as follows:
# - Implement the `sklearn` [**MeanShift** clustering algorithm](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.MeanShift.html#sklearn.cluster.MeanShift) to cluster the pokemon data based on any of the statistical attributes of pokemon.
# - Visualise the resulting clusters
# - Briefly answer the following question in the final box supplied: What information could you infer from using the MeanShift clustering algorithm?

# %%
# Part 1: Implement the MeanShift algorithm (already imported in the first codebox)
centers = [[1, 1], [-1, -1], [1, -1]]
X = np.array(pokemon[['Total','HP','Attack','Defense','Speed','Sp. Atk','Sp. Def']])
clustering = MeanShift().fit(X)
labels = clustering.labels_
cluster_centers = clustering.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)
# Part 2: Visualise your results
colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, 0], X[my_members, 1], col + '.')
    plt.plot(cluster_center[0], cluster_center[1], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()

# %% [raw]
# Part 3: What information could you infer from using the MeanShift clustering algorithm?
#
# #### Your answer here #####
# We can conclude that all pokemons can be categorized into 4 groups.

# %% [markdown]
# ***

# %% [markdown]
# ### Exercise 4: Clusters of Buyers (Using Dataset #1)
#
# It appears many of the machine learning questions have been clustered into the last two labtests! In this section, you need to perform the following tasks:
# - Restrict the dataset only to purchases made where the Country is the United States.
# - Using a [LabelEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html), encode the states within USA
# - Implement a **k-means clustering** function using 3 clusters. (You may use `sklearn` or any other module in the conda distribution)
# - What is the average purchase price for each cluster?
#
# `Note: You may use any number of features in clustering`

# %%
# Part 1: US-Only
sales_data2 = sales_data[(sales_data['Country']=='United States')]
# Part 2: Encoding
le = LabelEncoder()
le.fit(sales_data2.State)
sales_data2.State = le.transform(sales_data2.State)
# Part 3: Clustering
# Out:
#     Transaction_date  Product  Price  Payment_Type                  Name  \
# 1        1/2/09 4:53      1.0   1200             1                Betina
# 2       1/2/09 13:08      1.0   1200             0     Federica e Andrea
# 4       1/4/09 12:56      2.0   3600             1               Gerd W
# 5       1/4/09 13:19      1.0   1200             1              LAURENCE
# 6       1/4/09 20:11      1.0   1200             0                 Fleur
# 7       1/2/09 20:09      1.0   1200             0                  adam
# 10       1/5/09 2:42      1.0   1200             2                 Stacy
# 12       1/2/09 9:16      1.0   1200             0                 Sean
# 13      1/5/09 10:08      1.0   1200             1               Georgia
# 14      1/2/09 14:18      1.0   1200             1               Richard
# 19       1/2/09 7:35      1.0   1200             2                  Hani
# 23       1/6/09 7:18      1.0   1200             1                asuman
# 25       1/1/09 2:24      1.0   1200             1                  Lisa
# 26       1/7/09 8:08      1.0   1200             2         Bryan Kerrene
# 28      1/1/09 20:21      1.0   1200             1                Maxine
# 29       1/8/09 0:42      1.0   1200             1                Family
# 30       1/8/09 3:56      1.0   1200             0             Katherine
# 31       1/8/09 3:16      1.0   1200             0                 Linda
# 33       1/3/09 9:03      1.0   1200             2                Sheila
# 35       1/6/09 7:46      1.0   1200             3                 Kelly
# 37      1/8/09 16:24      1.0   1200             1              jennifer
# 38       1/9/09 6:39      1.0   1200             0                Anneli
# 39      1/6/09 22:19      2.0   3600             3                  Ritz
# 40      1/6/09 23:00      2.0   3600             3                Sylvia
# 41       1/7/09 7:44      1.0   1200             0                 Marie
# 43      1/7/09 15:12      2.0   3600             1               Anabela
# 44      1/7/09 20:15      1.0   1200             3                Nicole
# 45      1/3/09 10:11      2.0   3600             1           Christiane
# 48     1/10/09 12:57      1.0   1200             3               Vanessa
# 50     1/10/09 12:05      1.0   1200             1                Karina
# ..               ...      ...    ...           ...                   ...
# 931     1/26/09 6:38      1.0   1200             1             Christian
# 935     1/26/09 8:00      1.0   1200             3            Elizabeth
# 936     1/11/09 8:41      1.0   1200             3               Juliann
# 937    1/21/09 10:32      1.0   1200             0                Julie
# 940    1/31/09 18:12      1.0   1200             1               matthew
# 941    1/22/09 15:35      1.0   1200             1                Steven
# 942     1/5/09 11:24      1.0   1200             3                 Angie
# 943    1/23/09 11:23      1.0   1200             0                Lauren
# 944     1/7/09 20:55      1.0   1200             0                Esther
# 945     1/13/09 9:40      1.0   1200             1             Elizabeth
# 946    1/25/09 15:18      2.0   3600             1          marie-louise
# 951     1/13/09 7:09      2.0   3600             3                  John
# 952     1/3/09 11:03      1.0   1200             0                 paula
# 954      1/5/09 7:55      1.0   1200             0              Isabelle
# 955    1/25/09 14:40      1.0   1200             1               Maureen
# 956    1/25/09 17:55      1.0   1200             1                 David
# 957     1/3/09 12:54      1.0   1200             2              caterina
# 962     1/10/09 9:32      2.0   3600             0                Cheryl
# 963    1/22/09 12:45      3.0   7500             1  Frank and Christelle
# 964     1/6/09 18:11      2.0   3600             0                Triona
# 966    1/25/09 10:50      1.0   1200             2               Phillip
# 967     1/14/09 8:38      1.0   1200             1               jingyan
# 969     1/7/09 18:15      1.0   1200             0                 Selma
# 970     1/3/09 21:19      1.0   1200             1         Doug and Tina
# 976    1/29/09 13:25      1.0   1200             2                  Hale
# 979    1/23/09 10:04      1.0   1200             0                 Kevin
# 985    1/28/09 11:19      1.0   1200             1              christal
# 986     1/7/09 17:48      1.0   1200             0                  Alex
# 995      1/1/09 4:24      3.0   7500             3                Pamela
# 997    1/12/09 21:30      1.0   1200             1                Julia
#
#                              City  State        Country Account_Created  \
# 1    Parkville                        25  United States     1/2/09 4:42
# 2    Astoria                          37  United States    1/1/09 16:21
# 4    Cahaba Heights                    1  United States  11/15/08 15:47
# 5    Mickleton                        32  United States   9/24/08 15:19
# 6    Peoria                           15  United States     1/3/09 9:38
# 7    Martin                           41  United States    1/2/09 17:43
# 10   New York                         35  United States     1/5/09 2:23
# 12   Shavano Park                     42  United States     1/2/09 8:32
# 13   Eagle                            14  United States  11/11/08 15:53
# 14   Riverside                        32  United States   12/9/08 12:07
# 19   Salt Lake City                   43  United States   12/30/08 5:44
# 23   Chula Vista                       4  United States     1/6/09 7:07
# 25   Sugar Land                       42  United States     1/1/09 1:56
# 26   New York                         35  United States     1/7/09 7:39
# 28   Morton                           15  United States   10/24/08 6:48
# 29   Los Gatos                         4  United States     1/8/09 0:28
# 30   New York                         35  United States     1/8/09 3:33
# 31   Miami                             9  United States     1/8/09 3:06
# 33   Brooklyn                         35  United States     1/3/09 8:47
# 35   Reston                           44  United States     1/6/09 7:30
# 37   Phoenix                           3  United States    1/8/09 15:57
# 38   Houston                          42  United States     1/9/09 5:09
# 39   Pittsfield                       46  United States    1/6/09 12:00
# 40   Pittsfield                       46  United States    1/6/09 12:00
# 41   Ball Ground                      10  United States     1/7/09 5:35
# 43   Flossmoor                        15  United States    1/5/09 19:55
# 44   Houston                          42  United States    1/7/09 17:17
# 45   Delray Beach                      9  United States     1/3/09 9:27
# 48   Sandy Springs                    10  United States    2/7/07 20:16
# 50   Fort Lauderdale                   9  United States    7/1/08 12:53
# ..                            ...    ...            ...             ...
# 931  Alexandria                       44  United States   1/25/09 10:13
# 935  Bluffton                         40  United States   1/23/09 11:12
# 936  Winter Spgs                       9  United States     1/8/08 7:24
# 937  Chelmsford                       20  United States   5/23/07 11:55
# 940  Cincinnati                       36  United States    4/2/06 11:49
# 941  Houston                          42  United States   2/24/08 16:57
# 942  Rodeo                             4  United States   1/25/08 16:50
# 943  Poughkeepsie                     35  United States    8/26/08 9:37
# 944  Cincinnati                       36  United States    1/7/09 20:25
# 945  North Eastham                    20  United States   1/26/05 19:09
# 946  Sitka                             0  United States    3/2/08 15:27
# 951  Chicago                          15  United States    1/8/09 13:49
# 952  Sammamish                        48  United States    1/1/09 22:43
# 954  Ewa Beach                        12  United States   12/31/08 7:40
# 955  Statesville                      29  United States   1/25/09 13:52
# 956  Kapaa                            12  United States   1/24/09 12:18
# 957  Burbank                           4  United States   12/30/08 8:39
# 962  Hilton Head                      40  United States   1/10/05 21:39
# 963  Valley Center                     4  United States   1/22/09 10:25
# 964  Swampscott                       20  United States     6/9/06 8:57
# 966  San Antonio                      42  United States   5/29/08 19:51
# 967  Bristol                          39  United States   3/12/07 15:14
# 969  Greenville                       42  United States    1/5/09 18:16
# 970  Pls Vrds Est                      4  United States  12/24/07 22:59
# 976  Morrison                          5  United States   11/3/05 18:14
# 979  Hollywood                         4  United States   5/30/06 20:25
# 985  Morrison                          5  United States   6/20/04 17:16
# 986  Augusta                          10  United States   6/10/05 20:25
# 995  Skaneateles                      35  United States  12/28/08 17:28
# 997  Madison                          49  United States  11/17/08 22:24
#
#         Last_Login  Latitude  Longitude
# 1      1/2/09 7:49  39.19500  -94.68194
# 2     1/3/09 12:32  46.18806 -123.83000
# 4     1/4/09 12:45  33.52056  -86.80250
# 5     1/4/09 13:04  39.79000  -75.23806
# 6     1/4/09 19:45  40.69361  -89.58889
# 7     1/4/09 20:01  36.34333  -88.85028
# 10     1/5/09 4:59  40.71417  -74.00639
# 12     1/5/09 9:05  29.42389  -98.49333
# 13    1/5/09 10:05  43.69556 -116.35306
# 14    1/5/09 11:01  40.03222  -74.95778
# 19    1/6/09 10:52  40.76083 -111.89028
# 23     1/7/09 7:08  32.64000 -117.08333
# 25    1/7/09 10:52  29.61944  -95.63472
# 26    1/7/09 12:38  40.71417  -74.00639
# 28    1/7/09 20:49  40.61278  -89.45917
# 29     1/8/09 3:39  37.22667 -121.97361
# 30     1/8/09 6:19  40.71417  -74.00639
# 31     1/8/09 6:34  25.77389  -80.19389
# 33    1/8/09 10:38  40.65000  -73.95000
# 35    1/8/09 12:40  38.96861  -77.34139
# 37    1/8/09 18:30  33.44833 -112.07333
# 38     1/9/09 7:11  29.76306  -95.36306
# 39    1/9/09 10:05  43.77222  -72.81333
# 40    1/9/09 10:05  43.77222  -72.81333
# 41    1/9/09 10:52  34.33806  -84.37667
# 43    1/9/09 16:03  41.54278  -87.68472
# 44    1/9/09 20:02  29.76306  -95.36306
# 45    1/10/09 9:46  26.46111  -80.07306
# 48   1/10/09 14:09  33.92417  -84.37861
# 50   1/10/09 16:33  26.12194  -80.14361
# ..             ...       ...        ...
# 931   2/26/09 7:16  38.80472  -77.04722
# 935   2/26/09 7:49  32.23694  -80.86056
# 936   2/26/09 8:17  28.69861  -81.30833
# 937   2/26/09 8:38  42.59972  -71.36778
# 940  2/26/09 12:03  39.16194  -84.45694
# 941  2/26/09 12:06  29.76306  -95.36306
# 942  2/26/09 12:15  38.01722 -122.28750
# 943  2/26/09 12:17  41.70028  -73.92139
# 944  2/26/09 12:24  39.16194  -84.45694
# 945  2/26/09 12:45  41.86500  -69.99167
# 946  2/26/09 12:58  57.05306 -135.33000
# 951  2/26/09 15:14  41.85000  -87.65000
# 952  2/26/09 15:30  47.64194 -122.07917
# 954  2/26/09 17:47  21.31556 -158.00722
# 955  2/26/09 18:38  35.78250  -80.88750
# 956  2/26/09 20:21  22.07833 -159.32194
# 957  2/26/09 20:22  34.18083 -118.30806
# 962   2/27/09 7:33  32.21611  -80.75278
# 963  2/27/09 10:49  33.21833 -117.03333
# 964  2/27/09 13:00  42.47083  -70.91806
# 966  2/27/09 14:44  29.42389  -98.49333
# 967  2/27/09 17:13  41.67694  -71.26667
# 969  2/27/09 19:07  33.13833  -96.11056
# 970  2/27/09 21:40  33.80056 -118.38917
# 976   2/28/09 8:27  39.65361 -105.19056
# 979   2/28/09 9:59  34.09833 -118.32583
# 985  2/28/09 17:18  39.65361 -105.19056
# 986  2/28/09 19:57  33.51722  -82.07583
# 995    3/1/09 7:21  42.94694  -76.42944
# 997   3/1/09 10:14  43.07306  -89.40111
#
# [462 rows x 12 columns]
